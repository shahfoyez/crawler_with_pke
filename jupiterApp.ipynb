# %%
import requests
from bs4 import BeautifulSoup
from csv import writer
import pake
import pke
from pke.unsupervised import *

from timeit import default_timer as timer
import re
import math
from collections import Counter
import sys
for path in sys.path:
    print(path)
print(pke.__file__)
# Out:
# C:\Users\Ashraff\crawlerFreelancerWithPKE
# C:\ProgramData\Anaconda3\python39.zip
# C:\ProgramData\Anaconda3\DLLs
# C:\ProgramData\Anaconda3\lib
# C:\ProgramData\Anaconda3
#
# C:\Users\Ashraff\AppData\Roaming\Python\Python39\site-packages
# C:\ProgramData\Anaconda3\lib\site-packages
# C:\ProgramData\Anaconda3\lib\site-packages\win32
# C:\ProgramData\Anaconda3\lib\site-packages\win32\lib
# C:\ProgramData\Anaconda3\lib\site-packages\Pythonwin
# C:\Users\Ashraff\crawlerFreelancerWithPKE\pke\__init__.py

# %%
def trade_spider(max_pages):
    page = 21
    with open('train.csv', 'w', encoding = 'utf8', newline='') as f:
        thewriter = writer(f)
        header = ['title', 'abstract', 'keyphrases']
        thewriter.writerow(header)
        while page <= max_pages:
            # url = "https://www.freelancer.com/jobs/php/"+str(page)+"/?languages=en&fixed=true&hourly=true"
            url = "https://www.freelancer.com/jobs/"+str(page)+"/?fixed=true&hourly=true&languages=en"
            print( url)
            source_code = requests.get( url )
            plain_text =  source_code.text
            soup = BeautifulSoup(plain_text, features="html.parser")

            # for link in soup.findAll('a', {'class': 'JobSearchCard-primary-heading-link'}):
            titles = soup.findAll('a', {'class': 'JobSearchCard-primary-heading-link'})
            abstracts = soup.findAll('p', {'class': 'JobSearchCard-primary-description'})
#             keyphrases = soup.findAll('div', {'class': 'JobSearchCard-primary-tags'})
            i = 1
            for link, link1 in zip (titles, abstracts):
                title = link.string
                abstract = link1.string
                title = title.strip()
                if not abstract:
                    abstract = "Empty String"
                else:
                    # to remove space/new line
                    abstract = " ".join(abstract.split())
                      
                # keyword extraction starts here
                doc =  title+" "+abstract
                outputs = {}
                elapsed_times = {}
                for model in [PAKE]:
                    outputs[model.__name__] = []
            
                    extractor = model()
                    start = timer()
                    # for i, doc in enumerate(tqdm(test)):
                    print("**********************Title + Abstract**********************")
                    print(doc)
                    extractor.load_document(input=doc, language='en')
                    extractor.grammar_selection(grammar="NP: {<ADJ>*<NOUN|PROPN>+}")
                    if model.__name__ in ["TfIdf"]:
                        extractor.candidate_weighting(df=df)
                    elif model.__name__ in ["TopicalPageRank"]:
                        extractor.candidate_weighting(lda_model=lda_model)
                    else:
                        extractor.candidate_weighting()
                    outputs[model.__name__].append([u for u,v in extractor.get_n_best(n=10, stemming=True)])
                    
                    
                phrase = ""
                for keyword in outputs[model.__name__][0]:
                    key = keyword.strip()
                    phrase += key+", "
                phrase = phrase.strip(", ")

                # inserting to csv
                info = [title, abstract, phrase]
                thewriter.writerow(info)
                print("**********************Content from page", i)
                i+=1
            page += 1

trade_spider(30)
# Out:
# https://www.freelancer.com/jobs/21/?fixed=true&hourly=true&languages=en
# **********************Title + Abstract**********************
# Xamarin App Developer Hello I have an App in Xamarin Forms which I needs to uploaded to App Store for iOS . It uses UIWebview which needs to be replaced with WKWebview as I am getting this issue when trying to upload , so needs to be updated & app needs to be uploaded to store .
# **********************After checking Similarity from pke pake model**********************
# ['xamarin app developer', 'xamarin forms', 'app store', 'ios', 'uiwebview', 'wkwebview', 'issue']
# **********************Top 10 from pke pake model*****************************************
# [('xamarin app developer', 4.2521283709051174e-05), ('xamarin forms', 0.0009713755053737429), ('app store', 0.002698690394059599), ('ios', 0.04670104510608643), ('uiwebview', 0.10061388124426905), ('wkwebview', 0.10061388124426905), ('issue', 0.14540255541488056)]
# **********************Content from page 1
# **********************Title + Abstract**********************
# Kickstarter expert I wish to launch a new product - Basharama on kickstarter [login to view URL]
# **********************After checking Similarity from pke pake model**********************
# ['kickstarter expert', 'new product', 'basharama', 'url']
# **********************Top 10 from pke pake model*****************************************
# [('kickstarter expert', 0.0008705073197596547), ('new product', 0.001334361283540894), ('basharama', 0.024501626908393772), ('url', 0.024501626908393772)]
# **********************Content from page 2
# **********************Title + Abstract**********************
# Advice & Guidance Premium Phone Website The project is for people in different fields to register on the site, set up a profile, and they can set their own availability or online/offline status. When user has chosen online, they can be called by anyone selecting for that guidance using a phone number with an extension.
# **********************After checking Similarity from pke pake model**********************
# ['guidance premium phone website', 'offline status', 'different fields', 'phone number', 'advice', 'project', 'people', 'site', 'profile', 'guidance', 'user', 'extension', 'own availability']
# **********************Top 10 from pke pake model*****************************************
# [('guidance premium phone website', 2.9289922181961315e-06), ('offline status', 0.001904000318031503), ('different fields', 0.002479822508379065), ('phone number', 0.0078731161294325), ('advice', 0.04359337094235702), ('project', 0.04359337094235702), ('people', 0.04359337094235702), ('site', 0.04359337094235702), ('profile', 0.04359337094235702), ('guidance', 0.057157387128548655)]
# **********************Content from page 3
# **********************Title + Abstract**********************
# Mobile Development Project Create two mobile applications as below: 1. Mobile application for customers mimicking features of existing customer web portal providing customers the ability to book repair service, check the status of their repair ticket, check the status of parts ordered, and receive notifications and alerts for various events such as parts arrived, technician on the way, etc and communicate and respond to company messages. 2. Mobile application for technicians to receive work orders with work details, and update work done, parts installed, services completed, and be able to receive customers' signatures and receive payments. using our existing payment gateway.
# **********************After checking Similarity from pke pake model**********************
# ['mobile development project', 'mobile applications', 'customer web portal', 'mobile application', 'repair service', 'repair ticket', 'company messages', 'customers', 'parts', 'work orders', 'work details', 'update work', 'status', 'payment gateway', 'features', 'ability', 'notifications', 'alerts', 'way', 'technicians', 'services', 'signatures', 'payments', 'various events']
# **********************Top 10 from pke pake model*****************************************
# [('mobile development project', 0.0001263345071907803), ('mobile applications', 0.005694633455970145), ('customer web portal', 0.005776718641202651), ('repair service', 0.026373762470177364), ('repair ticket', 0.026373762470177364), ('company messages', 0.0313943810566665), ('customers', 0.054464114483700754), ('parts', 0.054464114483700754), ('work orders', 0.06006418775428384), ('work details', 0.06006418775428384)]
# **********************Content from page 4
# **********************Title + Abstract**********************
# Book Keeping Book Keeping wherein we need help in understanding Accounting entries
# **********************After checking Similarity from pke pake model**********************
# ['book keeping book keeping', 'accounting entries', 'help']
# **********************Top 10 from pke pake model*****************************************
# [('book keeping book keeping', 4.5469557513459465e-07), ('accounting entries', 0.0009037025276426394), ('help', 0.03522921073680174)]
# **********************Content from page 5
# **********************Title + Abstract**********************
# Ongoing Project Management - Managing a team of 4 developers, 2 designers and 3 social media experts We are looking for a Management Guru. You must have experience with managing large/medium teams who work on social media platforms, cultivating and growing a community by engagement, ideas for onboarding, creating and managing groups, commenting and responding in groups or in direct messages and tracking metrics to show progress. Working within an overall timeline and structure. Prior to starting, you will review our existing platforms, procedures, processes, provide an assessment and brief plan for moving forward. ***Please read full project details.*** We are looking for someone that is fluent in English, written and spoken. We will need to have a video call to test your connectivity as well as to get to know you. Responsibilities: Under general supervision and direction, manage the p...
# **********************After checking Similarity from pke pake model**********************
# ['ongoing project management', 'social media experts', 'management guru', 'medium teams', 'direct messages', 'team', 'developers', 'designers', 'groups', 'overall timeline', 'brief plan', 'experience', 'community', 'engagement', 'ideas', 'metrics', 'progress', 'platforms', 'general supervision', 'structure', 'full project details', 'english', 'procedures', 'processes', 'assessment', 'connectivity', 'responsibilities', 'direction', 'video call', 'p']
# **********************Top 10 from pke pake model*****************************************
# [('ongoing project management', 0.0008156397599045382), ('social media experts', 0.00085481645680236), ('management guru', 0.0011102311879988215), ('medium teams', 0.03393494124066456), ('direct messages', 0.047576804652896106), ('team', 0.05988903092072394), ('developers', 0.05988903092072394), ('designers', 0.05988903092072394), ('groups', 0.07581071816277704), ('overall timeline', 0.08681746703814758)]
# **********************Content from page 6
# **********************Title + Abstract**********************
# Sharing Paring jobs Here, I have a plan of having profit from both side in equal amount I want projects of yours where I can help out others like MS word projects , excel works etc.. conversion of jpg. files to pdf . *Plan* is : Project fund will be given to me of ₹600 If I will do half work then full refund work done properly then the half of the money will be refunded back... Ex :- Amount while giving project amount will be ₹600 Work done (Fully)- Then amount will be half distributed (300+300 =600) Work incomplete then -Full refund !! ~Thank You ""The above plan will be followed strictly from my side rest depends ...
# **********************After checking Similarity from pke pake model**********************
# ['paring jobs', 'excel works', 'project fund', 'projects', 'ms word projects', 'profit', 'conversion', 'plan', 'work', 'half', 'full refund work', 'files', 'money', 'side rest', 'equal amount', 'jpg .', 'project amount', 'yours', 'others', 'ex', '₹']
# **********************Top 10 from pke pake model*****************************************
# [('paring jobs', 0.002653593510565188), ('excel works', 0.002653593510565188), ('project fund', 0.0322026890848527), ('projects', 0.040674400563488235), ('ms word projects', 0.04759209308552431), ('profit', 0.05144483052773666), ('conversion', 0.05144483052773666), ('plan', 0.06469114444391519), ('work', 0.10574440917744864), ('half', 0.14973738009590531)]
# **********************Content from page 7
# **********************Title + Abstract**********************
# Resume Update -- 2 I need to update my professional Resume.
# **********************After checking Similarity from pke pake model**********************
# ['resume update', 'professional resume']
# **********************Top 10 from pke pake model*****************************************
# [('resume update', 0.0006015267065440236), ('professional resume', 0.0010639671487494696)]
# **********************Content from page 8
# **********************Title + Abstract**********************
# Private project or contest #35340080 Empty String
# **********************After checking Similarity from pke pake model**********************
# ['private project', 'empty string']
# **********************Top 10 from pke pake model*****************************************
# [('private project', 0.001103243566061261), ('empty string', 2.000000000000003)]
# **********************Content from page 9
# **********************Title + Abstract**********************
# Creative Copywriter Full Job Description Job Description: Create written content including product listings, advertisement and marketing campaigns, social media content, EDM Create and deliver delightful ideas for promotions Work closely with internal teams and vendors to maintain smooth business workflow Perform ad-hoc marketing tasks and projects as assigned Job Requirements: Any related discipline with more than 1 year relevant working experience Responsible, self-motivated and well disciplined Strong ownership with good execution skills Able to adapt fast-changing ecommerce work attitude Independently and effectively work under daily time constraints Interest in sexual wellness and sex positivity, and promote sex education will be a huge advantage Experience in social media management is a plus Experien...
# **********************After checking Similarity from pke pake model**********************
# ['creative copywriter full job description job description', 'fast-changing ecommerce work attitude', 'daily time constraints interest', 'social media content', 'ad-hoc marketing tasks', 'huge advantage experience', 'smooth business workflow', 'relevant working experience', 'good execution skills', 'job requirements', 'edm create', 'marketing campaigns', 'sex positivity', 'sex education', 'strong ownership', 'product listings', 'delightful ideas', 'internal teams', 'related discipline', 'sexual wellness', 'experien', 'content', 'advertisement', 'promotions', 'vendors', 'projects', 'year']
# **********************Top 10 from pke pake model*****************************************
# [('creative copywriter full job description job description', 2.6833534463294817e-09), ('fast-changing ecommerce work attitude', 1.0266699491783375e-06), ('daily time constraints interest', 1.4631665389948573e-06), ('social media content', 3.093537239006456e-05), ('ad-hoc marketing tasks', 3.787144368950023e-05), ('huge advantage experience', 3.9418134962118705e-05), ('smooth business workflow', 4.566051622335927e-05), ('relevant working experience', 5.151681108631145e-05), ('good execution skills', 5.638858232562272e-05), ('job requirements', 0.0004732095739347933)]
# **********************Content from page 10
# **********************Title + Abstract**********************
# Need someone who knows assembly language I need someone who knows assembly language and can make a digital clock using this language. URGENT.
# **********************After checking Similarity from pke pake model**********************
# ['assembly language', 'digital clock', 'urgent']
# **********************Top 10 from pke pake model*****************************************
# [('assembly language', 0.0010971176252203203), ('digital clock', 0.002196867731031527), ('urgent', 0.10077184458446668)]
# **********************Content from page 11
# **********************Title + Abstract**********************
# ux/ui developer create a ux/ui developer Requirement: · Good at Photoshop, Illustrator, Figma and Adobe XD. · Good at UI/UX Designing and Analysis (Website, Mobile App, Wireframes. · Creative Logo Designing, layout designing, Banner Designing. · Good English Communication skills. · Prepare and present rough drafts to internal teams and key stakeholders. · Team spirit; strong communication skills to collaborate with various stakeholders
# **********************After checking Similarity from pke pake model**********************
# ['good english communication skills', 'creative logo designing', 'mobile app', 'banner designing', 'strong communication skills', 'layout designing', 'photoshop', 'illustrator', 'figma', 'ui developer requirement', 'key stakeholders', 'rough drafts', 'analysis', 'website', 'wireframes', 'team spirit', 'internal teams', 'adobe xd', 'various stakeholders', 'ux designing']
# **********************Top 10 from pke pake model*****************************************
# [('good english communication skills', 0.001633444784823316), ('creative logo designing', 0.007001078077309978), ('mobile app', 0.013532785072473106), ('banner designing', 0.019977626050587824), ('strong communication skills', 0.02696323173331275), ('layout designing', 0.030395067297004214), ('photoshop', 0.03625365535680305), ('illustrator', 0.03625365535680305), ('figma', 0.03625365535680305), ('ui developer requirement', 0.0434032817378915)]
# **********************Content from page 12
# **********************Title + Abstract**********************
# I need a photo editor  -- 2 I photographed a wedding and I don’t have time to edit it atleast 500 images
# **********************After checking Similarity from pke pake model**********************
# ['photo editor', 'wedding', 'time', 'images']
# **********************Top 10 from pke pake model*****************************************
# [('photo editor', 0.0009247938619094762), ('wedding', 0.030396371632413578), ('time', 0.030396371632413578), ('images', 0.030396371632413578)]
# **********************Content from page 13
# **********************Title + Abstract**********************
# I need a photo editor I photographed a wedding and I don’t have time to edit it atleast 500 images
# **********************After checking Similarity from pke pake model**********************
# ['photo editor', 'wedding', 'time', 'images']
# **********************Top 10 from pke pake model*****************************************
# [('photo editor', 0.0009247938619094762), ('wedding', 0.030396371632413578), ('time', 0.030396371632413578), ('images', 0.030396371632413578)]
# **********************Content from page 14
# **********************Title + Abstract**********************
# Need a chemical engineer -- 2 Need a chemical engineer to help with drawing a process flow diagram for a chemical process. 10 minutes job if you know what you are dealing with.
# **********************After checking Similarity from pke pake model**********************
# ['chemical engineer', 'chemical process', 'minutes job', 'diagram']
# **********************Top 10 from pke pake model*****************************************
# [('chemical engineer', 0.00054546204531566), ('chemical process', 0.00109092409063132), ('minutes job', 0.019991925092942883), ('diagram', 0.04477379423336671)]
# **********************Content from page 15
# **********************Title + Abstract**********************
# Calculator Graduate in information technology,. CHM 'O' level , Strength -. Hard work -. Positive attitude
# **********************After checking Similarity from pke pake model**********************
# ['calculator graduate', 'information technology', 'hard work', 'positive attitude', 'chm', 'strength', 'level', 'o']
# **********************Top 10 from pke pake model*****************************************
# [('calculator graduate', 0.0016484155303590142), ('information technology', 0.0025313858174280434), ('hard work', 0.06079818247879544), ('positive attitude', 0.08392331223756334), ('chm', 0.10522297891038043), ('strength', 0.10522297891038043), ('level', 0.15522890109001378), ('o', 199999983451.92715)]
# **********************Content from page 16
# **********************Title + Abstract**********************
# Text Detection & recognition OCR i want you to extract specific information from invoice. u are free to use any available open source like PaddleOCR, Tessract, easyOCR etc...
# **********************After checking Similarity from pke pake model**********************
# ['text detection', 'recognition ocr', 'specific information', 'available open source', 'invoice', 'paddleocr', 'tessract']
# **********************Top 10 from pke pake model*****************************************
# [('text detection', 0.0010854848190658514), ('recognition ocr', 0.0010854848190658514), ('specific information', 0.0019443253491543233), ('available open source', 0.00308413366371878), ('invoice', 0.039194276471799905), ('paddleocr', 0.08992946662724807), ('tessract', 0.08992946662724807)]
# **********************Content from page 17
# **********************Title + Abstract**********************
# Convert web pages to React Js We are looking for experienced developers with ReactJS. We will inform you of the details in connection with each other. check it.
# **********************After checking Similarity from pke pake model**********************
# ['convert web pages', 'experienced developers', 'reactjs', 'details', 'connection', 'react js']
# **********************Top 10 from pke pake model*****************************************
# [('convert web pages', 9.998349559907904e-05), ('experienced developers', 0.002854162473771596), ('reactjs', 0.03103334821725336), ('details', 0.1443287221233458), ('connection', 0.1443287221233458)]
# **********************Content from page 18
# **********************Title + Abstract**********************
# Entrepreneur looking for an Experienced SCRIPT WRITER Our company is a growing data science startup completely remotely based. Our mission is to provide the best data science education tools and career platform for all aspiring data scientists looking for jobs or....
# **********************After checking Similarity from pke pake model**********************
# ['best data science education tools', 'experienced script writer', 'data science startup', 'data scientists', 'career platform', 'entrepreneur', 'company', 'mission', 'jobs']
# **********************Top 10 from pke pake model*****************************************
# [('best data science education tools', 1.645759991199019e-05), ('experienced script writer', 2.9869084552172248e-05), ('data science startup', 0.00015472031831699704), ('data scientists', 0.00745197474431705), ('career platform', 0.01820520544875652), ('entrepreneur', 0.042552149589249855), ('company', 0.042552149589249855), ('mission', 0.1337150021652442), ('jobs', 0.1337150021652442)]
# **********************Content from page 19
# **********************Title + Abstract**********************
# Restaurant design, kitchen layout for USA territory.. Hello to all, I am looking for someone to create a restaurant design opted for the USA. Meaning, you must have prior experience designing a restaurant dining room, kitchen and bathrooms for businesses in the USA. This is what I've done so far... 1. I already have the floor plan laid out with the equipment and workflow. 2. I have created a folder in Pinterest so you can get an idea of what I am looking for. 3. I will be needing your experience in order to suggest better workflow options and designs that will help me optimize my budget. Here are the requirements: 1. You must have prior experience with restaurant layouts. 2. Proof of past work of commercial kitchens, restaurant layouts 3. Must design Restaurant with current products that are available to purchase either online o...
# **********************After checking Similarity from pke pake model**********************
# ['usa territory', 'kitchen layout', 'restaurant dining room', 'restaurant design', 'restaurant layouts', 'prior experience', 'floor plan', 'better workflow options', 'meaning', 'bathrooms', 'businesses', 'past work', 'pinterest', 'commercial kitchens', 'current products', 'workflow', 'equipment', 'folder', 'idea', 'order', 'designs', 'budget', 'requirements', 'proof', 'online o']
# **********************Top 10 from pke pake model*****************************************
# [('usa territory', 0.00386861689536306), ('kitchen layout', 0.007265810782352682), ('restaurant dining room', 0.021912988776657774), ('restaurant design', 0.029607902791772646), ('restaurant layouts', 0.037992596178873815), ('prior experience', 0.07926693305607291), ('floor plan', 0.09653539519508328), ('better workflow options', 0.13001164364042614), ('meaning', 0.19112748808241845), ('bathrooms', 0.19112748808241845)]
# **********************Content from page 20
# **********************Title + Abstract**********************
# Need an app like Exness TP Global with full feautres Hi ,i want an app like exness like Trading Broker app ,with both Platform ,android and ios Please let me know your previous projects and also i need full support till the app launch
# **********************After checking Similarity from pke pake model**********************
# ['trading broker app', 'app launch', 'previous projects', 'exness', 'platform', 'exness tp global', 'android', 'ios', 'full feautres', 'full support']
# **********************Top 10 from pke pake model*****************************************
# [('trading broker app', 1.7157597927799848e-05), ('app launch', 0.0008990870146912728), ('previous projects', 0.001710260216300749), ('exness', 0.026298859858657736), ('platform', 0.026568872485026426), ('exness tp global', 0.029262848027984983), ('android', 0.03702998563872229), ('ios', 0.03702998563872229), ('full feautres', 2.0000000000000018), ('full support', 2.0000000000000018)]
# **********************Content from page 21
# **********************Title + Abstract**********************
# Freelance Content Editor We are looking for awesome editors who love Editing! We need you to edit and deliver consistent high-quality content.
# **********************After checking Similarity from pke pake model**********************
# ['freelance content editor', 'consistent high-quality content', 'awesome editors', 'editing']
# **********************Top 10 from pke pake model*****************************************
# [('freelance content editor', 5.850030542221823e-05), ('consistent high-quality content', 0.0008523170784972052), ('awesome editors', 0.0015989291700719188), ('editing', 0.039954682789842065)]
# **********************Content from page 22
# **********************Title + Abstract**********************
# Assistant supervisor lvl I am having an international opportunity for youngsters through which you can earn 30k-35k per Month. You have to work through online.
# **********************After checking Similarity from pke pake model**********************
# ['assistant supervisor lvl', 'international opportunity', 'month', 'youngsters', 'online']
# **********************Top 10 from pke pake model*****************************************
# [('assistant supervisor lvl', 6.536238345736502e-05), ('international opportunity', 0.002061672565133507), ('month', 0.028171257929188), ('youngsters', 0.040218329855935465), ('online', 0.12704470021859623)]
# **********************Content from page 23
# **********************Title + Abstract**********************
# Subtitle for video I need subtitle for this below link video. Please check video before bid Thanks These are two video. Budget $15
# **********************After checking Similarity from pke pake model**********************
# ['link video', 'bid thanks', 'subtitle', 'budget']
# **********************Top 10 from pke pake model*****************************************
# [('link video', 0.0031880487732787594), ('bid thanks', 0.016847844307493042), ('subtitle', 0.020623060064621956), ('budget', 0.212865966257502)]
# **********************Content from page 24
# **********************Title + Abstract**********************
# Linux Operating System Development With C Hello, For this job, I need an expert with the Linux base system, who understands the ins and outs of the kernal very well. I will give a zip file, with a C soure code and other 3 other files located in it. There will be 9 asked, those questions will be based on the functionality of these files. This is a very small job, and needs to be done by December 5th. Feel free to view the sample code, the questions will be given once the job has been accepted.
# **********************After checking Similarity from pke pake model**********************
# ['linux operating system development', 'linux base system', 'zip file', 'december 5th', 'expert', 'ins', 'outs', 'kernal', 'sample code', 'small job', 'questions', 'files', 'c soure code', 'functionality', 'c hello']
# **********************Top 10 from pke pake model*****************************************
# [('linux operating system development', 1.5901239224574164e-06), ('linux base system', 7.20271556877615e-05), ('zip file', 0.030368907059018676), ('december 5th', 0.0524800431928121), ('expert', 0.05631619285725728), ('ins', 0.05631619285725728), ('outs', 0.05631619285725728), ('kernal', 0.05631619285725728), ('sample code', 0.06269078478213384), ('small job', 0.06599933204500852)]
# **********************Content from page 25
# **********************Title + Abstract**********************
# do-follow backlinks with indexing and not blocked by robots.txt or any meta I need tons of do-follow backlinks with indexing and not blocked by or any meta in page source, to make sure you're not spamming write this word purple in your offer so I can see it and make sure you provide good backlinks like edu and gov
# **********************After checking Similarity from pke pake model**********************
# ['do-follow backlinks', 'good backlinks', 'page source', 'word purple', 'meta', 'indexing', 'tons', 'offer', 'edu', 'gov']
# **********************Top 10 from pke pake model*****************************************
# [('do-follow backlinks', 0.0008999235240596225), ('good backlinks', 0.0011259662900221206), ('page source', 0.0012823957898200464), ('word purple', 0.0012823957898200464), ('meta', 0.01487232983211899), ('indexing', 0.021751810320509792), ('tons', 0.035787614576932816), ('offer', 0.035787614576932816), ('edu', 0.035787614576932816), ('gov', 0.035787614576932816)]
# **********************Content from page 26
# **********************Title + Abstract**********************
# Social Media Content Creation We are in need of a talented individual or company to help create social media contents for our business. Persons must have a good knowledge in social media management and marketing as well as a good eye for post design. Posts must include videos, carousels, reels, stories, etc. Graphics design skills are extremely important too. Thank you
# **********************After checking Similarity from pke pake model**********************
# ['social media content creation', 'social media contents', 'talented individual', 'graphics design skills', 'good knowledge', 'good eye', 'post design', 'need', 'company', 'business', 'persons', 'marketing', 'posts', 'videos', 'carousels', 'reels', 'stories']
# **********************Top 10 from pke pake model*****************************************
# [('social media content creation', 6.963943771974553e-06), ('social media contents', 0.00031908143043820594), ('talented individual', 0.009506465786495005), ('graphics design skills', 0.013344918065715609), ('good knowledge', 0.02851272522651336), ('good eye', 0.02851272522651336), ('post design', 0.028905435903442175), ('need', 0.05371455971544594), ('company', 0.05371455971544594), ('business', 0.05371455971544594)]
# **********************Content from page 27
# **********************Title + Abstract**********************
# OCR Extract specific text from Random invoices i want you to extract specific information from invoice. u are free to use any available open source like PaddleOCR, Tessract, easyOCR etc...
# **********************After checking Similarity from pke pake model**********************
# ['ocr extract', 'random invoices', 'specific text', 'specific information', 'available open source', 'invoice', 'paddleocr', 'tessract']
# **********************Top 10 from pke pake model*****************************************
# [('ocr extract', 0.0007616896223048036), ('random invoices', 0.001188017703683885), ('specific text', 0.0015843503770860876), ('specific information', 0.0015843503770860876), ('available open source', 0.0036726074593560116), ('invoice', 0.041328609131316946), ('paddleocr', 0.09310601488731177), ('tessract', 0.09310601488731177)]
# **********************Content from page 28
# **********************Title + Abstract**********************
# 20 dollars to copy a WordPress theme, exactly the same. Do not exceed the budgeted amount. Complete within 2 hours 20 dollars to copy a WordPress theme, exactly the same. Do not exceed the budgeted amount. Complete within 2 hours
# **********************After checking Similarity from pke pake model**********************
# ['wordpress theme', 'dollars', 'hours', 'amount']
# **********************Top 10 from pke pake model*****************************************
# [('wordpress theme', 0.005981659658282736), ('dollars', 0.0660930452726774), ('hours', 0.10690751676384135), ('amount', 99999991725.96358)]
# **********************Content from page 29
# **********************Title + Abstract**********************
# Back Links Needed for a website Send me the number of back links you can create and the costs. I will need a report for validation. No website scan needed, just back links. Send me me price and numbers of back links per week or based on price. Niche Automotive Spam score less than 34 DR 30 Ahrefs
# **********************After checking Similarity from pke pake model**********************
# ['niche automotive spam score', 'number', 'costs', 'links', 'website', 'price', 'report', 'validation', 'ahrefs', 'numbers', 'week', 'dr']
# **********************Top 10 from pke pake model*****************************************
# [('niche automotive spam score', 0.0053975120405262925), ('number', 0.05408830012901778), ('costs', 0.05408830012901778), ('links', 0.05567356792782716), ('website', 0.062427589722231246), ('price', 0.10910406761187648), ('report', 0.1656889984032628), ('validation', 0.1656889984032628), ('ahrefs', 0.2010985688269904), ('week', 0.261766382555383)]
# **********************Content from page 30
# **********************Title + Abstract**********************
# Medical immaging segmentation I need someone who is an expert in deeplearning
# **********************After checking Similarity from pke pake model**********************
# ['segmentation', 'expert']
# **********************Top 10 from pke pake model*****************************************
# [('segmentation', 0.030396371632413578), ('expert', 0.030396371632413578)]
# **********************Content from page 31
# **********************Title + Abstract**********************
# Need an ArchiveLink content server Prototype Project Overview I would like to have an SAP ArchiveLink HTTP 6.4 content server prototype created in Python. I'm okay with the prototype using any free python packages. It needs to run on both Windows and Linux. Since it is Python this should not be a problem. The prototype needs to properly handle SAP (BC-SRV-ARL) requests. It’s a simple protocol, but one component of the requests (the secKey) is complex. I am looking for the prototype because I don't know how to decode and use the secKey. You need to develop and test this prototype on your own systems and with your own SAP. I only want to be sent code you believe meets the requirements. Prototype Requirements I need for the prototype to accept the key sent by SAP by the putCert request and use that to decode subs...
# **********************After checking Similarity from pke pake model**********************
# ['archivelink content server prototype project overview', 'sap archivelink http', 'free python packages', 'prototype', 'python', 'sap', 'simple protocol', 'requests', 'decode subs', 'seckey', 'windows', 'linux', 'putcert request', 'bc-srv-arl', 'problem', 'component', 'code', 'key', 'own systems']
# **********************Top 10 from pke pake model*****************************************
# [('archivelink content server prototype project overview', 1.6990593229740153e-08), ('sap archivelink http', 0.00017616364025424867), ('free python packages', 0.004948505847313019), ('prototype', 0.028165181202084586), ('python', 0.04622864734452222), ('sap', 0.07447551682132708), ('simple protocol', 0.1311797396802065), ('requests', 0.13812434456190115), ('decode subs', 0.14188744879188248), ('seckey', 0.1465243127727565)]
# **********************Content from page 32
# **********************Title + Abstract**********************
# Design the logo We need someone to design our startup's portfolio
# **********************After checking Similarity from pke pake model**********************
# ['logo', 'startup', 'portfolio']
# **********************Top 10 from pke pake model*****************************************
# [('logo', 0.034588515384495436), ('startup', 0.034588515384495436), ('portfolio', 0.034588515384495436)]
# **********************Content from page 33
# **********************Title + Abstract**********************
# Nonparametric Statistics Need an expert who can handle nonparametric statistics project remotely.
# **********************After checking Similarity from pke pake model**********************
# ['nonparametric statistics project', 'expert']
# **********************Top 10 from pke pake model*****************************************
# [('nonparametric statistics project', 2.8795868714924375e-05), ('expert', 0.03498516242744211)]
# **********************Content from page 34
# **********************Title + Abstract**********************
# Master Affordable django developer im looking for a django developer to create and develop a backend. the project front end is developed with flutter, so I prefer the developer to have some dart knowledge as well. the app might require a smart contract connection to it.
# **********************After checking Similarity from pke pake model**********************
# ['master affordable django developer', 'smart contract connection', 'dart knowledge', 'backend', 'project', 'flutter', 'app', 'front end']
# **********************Top 10 from pke pake model*****************************************
# [('master affordable django developer', 4.2789639486348615e-06), ('smart contract connection', 0.009122743426887184), ('dart knowledge', 0.022243425281055045), ('backend', 0.047457635010247905), ('project', 0.14751074950988302), ('flutter', 0.14751074950988302), ('app', 0.201342556464509), ('front end', 1.9999999999999998)]
# **********************Content from page 35
# **********************Title + Abstract**********************
# Editor de vídeo para YouTube (3$/h) Necesito editor hispanohablante para vídeos y shorts estilo @patrickdang/videos y @patrickdang/shorts
# **********************After checking Similarity from pke pake model**********************
# ['necesito editor hispanohablante', 'vídeo para youtube', 'editor', '@patrickdang', 'videos y @patrickdang', 'vídeos y']
# **********************Top 10 from pke pake model*****************************************
# [('necesito editor hispanohablante', 2.7235060913850552e-05), ('vídeo para youtube', 2.7235060913850555e-05), ('editor', 0.029514913612567566), ('@patrickdang', 0.029514913612567566), ('videos y @patrickdang', 0.033358545338573506), ('vídeos y', 2.0000000000000018)]
# **********************Content from page 36
# **********************Title + Abstract**********************
# Wordpress (LMS Plugins) for my LMS Website -- 3 Hi Wordpress (LMS Plugins) professionals, Suggest me for wordpress LMS plugin for course content listing tutorial blog, in my LMS Website Refer This for Different LMS Plugins for Course Content Creation & Presentation.. Require: What Are You Looking for in These WordPress LMS Plugins? My Requirement: Refer this for my Required Lasyout in Course Page (my Website - Courses Pages) Curriculum must be similar to this way of Presentation. Setup the appripriate Plugin & Also Add some content (sample) so that I will edit it once Im ready with my Course content. I think this is appropriate LMS Plugin.. "Learnpress LMS" Create course Manage course Any Issues? no worry. Pls reply to discuss in detail & make the Deal Btw. Little Low Budget, as its simple task, for Wordpr...
# **********************After checking Similarity from pke pake model**********************
# ['wordpress lms plugins', 'course content creation', 'lms website', 'tutorial blog', 'course page', 'learnpress lms', 'courses pages', 'wordpress', 'create course', 'required lasyout', 'appripriate plugin', 'presentation', 'little low budget', 'deal btw', 'professionals', 'requirement', 'curriculum', 'simple task', 'way', 'issues', 'wordpr', 'setup', 'sample', 'worry', 'detail']
# **********************Top 10 from pke pake model*****************************************
# [('wordpress lms plugins', 3.48360657767027e-05), ('course content creation', 0.0003018980713069853), ('lms website', 0.001600543911783377), ('tutorial blog', 0.003661829652887029), ('course page', 0.009700209283096778), ('learnpress lms', 0.010687975630958116), ('wordpress', 0.014014092412455595), ('create course', 0.015959083713389187), ('required lasyout', 0.02183765648163855), ('appripriate plugin', 0.03156020517634673)]
# **********************Content from page 37
# **********************Title + Abstract**********************
# Video Editor We are in need of a video editor to edit sports videos in a large project. There are roughly 50 videos of 4-6 minutes that need editing in the next 45 days. We already have a Premier Template to use and would require the editor to put the clips together, use their initiative to add the broll (that we provide), create 1 or 2 graphics per video and add short text titles during the video. (Video editing must be in Premier as that is our template) Here is an example of one our videos and you can see the text and graphics we are referring to:
# **********************After checking Similarity from pke pake model**********************
# ['large project', 'video editor', 'sports videos', 'short text titles', 'premier template', 'video editing', 'need', 'graphics', 'minutes', 'days', 'text', 'clips', 'initiative', 'broll', 'example']
# **********************Top 10 from pke pake model*****************************************
# [('large project', 0.0039635207614078264), ('video editor', 0.0050578688847643495), ('sports videos', 0.005219493851940786), ('short text titles', 0.013670704683423344), ('premier template', 0.02059817583409726), ('video editing', 0.02944569820451064), ('need', 0.087605385387142), ('graphics', 0.09259389205801738), ('minutes', 0.16330633338915537), ('days', 0.16330633338915537)]
# **********************Content from page 38
# **********************Title + Abstract**********************
# adding vpn sdk from aura developer  -- 2 developer should have account with developer. aura .com developer must add vpn sdk in our exiting android project thank you
# **********************After checking Similarity from pke pake model**********************
# ['vpn sdk', 'aura developer', 'android project', 'account']
# **********************Top 10 from pke pake model*****************************************
# [('vpn sdk', 0.002566987117830145), ('aura developer', 0.003962142373066654), ('android project', 0.020757325344395863), ('account', 0.045699752912899474)]
# **********************Content from page 39
# **********************Title + Abstract**********************
# Convert Excel spreadsheet into membership dashboard website I have an Excel spreadsheet containing various charts and outputs calculated using user input values. The spreadsheet has a Dashboard tab and other tabs representing the pages required. The main requirement of this project is the ability to convert the Excel document into a fully functioning dynamic website. 1. A website where users can sign up for free with just their name, email and password. 2. Once signed up, users input their information for the calculations to run (full account setup). Until this is completed, they should see a holding page. 3. A dashboard page to show high level charts/graphs etc. There will also be other pages where the user can see more specific information. All of this is contained in the spreadsheet. 4. The user can upgrade their account to a paid membership...
# **********************After checking Similarity from pke pake model**********************
# ['convert excel spreadsheet', 'user input values', 'membership dashboard website', 'dashboard tab', 'excel document', 'dashboard page', 'functioning dynamic website', 'outputs', 'high level charts', 'main requirement', 'users', 'user', 'website', 'specific information', 'project', 'ability', 'pages', 'membership', 'email', 'password', 'account', 'calculations', 'graphs', 'full account setup', 'other tabs', 'various charts', 'name']
# **********************Top 10 from pke pake model*****************************************
# [('convert excel spreadsheet', 0.001645436874716093), ('user input values', 0.005426719213182259), ('membership dashboard website', 0.007114558361787176), ('dashboard tab', 0.02175952764878156), ('excel document', 0.022437780763496236), ('dashboard page', 0.03836573981905172), ('functioning dynamic website', 0.05024823480956806), ('outputs', 0.0638725258531049), ('high level charts', 0.08816049608590742), ('main requirement', 0.09912279561281803)]
# **********************Content from page 40
# **********************Title + Abstract**********************
# Wordpress (LMS Plugins) for my LMS Website -- 2 Hi Wordpress (LMS Plugins) professionals, Suggest me for wordpress LMS plugin for course content listing tutorial blog, in my LMS Website Refer This for Different LMS Plugins for Course Content Creation & Presentation.. Require: What Are You Looking for in These WordPress LMS Plugins? My Requirement: Refer this for my Required Lasyout in Course Page (my Website - Courses Pages) Curriculum must be similar to this way of Presentation. Setup the appripriate Plugin & Also Add some content (sample) so that I will edit it once Im ready with my Course content. I think this is appropriate LMS Plugin.. "Learnpress LMS" Create course Manage course Any Issues? no worry. Pls reply to discuss in detail & make the Deal Btw. Little Low Budget, as its simple task, for Wordpr...
# **********************After checking Similarity from pke pake model**********************
# ['wordpress lms plugins', 'course content creation', 'lms website', 'tutorial blog', 'course page', 'learnpress lms', 'courses pages', 'wordpress', 'create course', 'required lasyout', 'appripriate plugin', 'presentation', 'little low budget', 'deal btw', 'professionals', 'requirement', 'curriculum', 'simple task', 'way', 'issues', 'wordpr', 'setup', 'sample', 'worry', 'detail']
# **********************Top 10 from pke pake model*****************************************
# [('wordpress lms plugins', 3.48360657767027e-05), ('course content creation', 0.0003018980713069853), ('lms website', 0.001600543911783377), ('tutorial blog', 0.003661829652887029), ('course page', 0.009700209283096778), ('learnpress lms', 0.010687975630958116), ('wordpress', 0.014014092412455595), ('create course', 0.015959083713389187), ('required lasyout', 0.02183765648163855), ('appripriate plugin', 0.03156020517634673)]
# **********************Content from page 41
# **********************Title + Abstract**********************
# Vuejs + Laravel Hello We use this theme Then we need to make some work on it. We're looking for someone can work with us for long term You should know very well Vuejs and Laravel
# **********************After checking Similarity from pke pake model**********************
# ['laravel', 'vuejs', 'long term', 'theme', 'work']
# **********************Top 10 from pke pake model*****************************************
# [('laravel', 0.02440364619581851), ('vuejs', 0.027983181644274466), ('long term', 0.03160574299642829), ('theme', 0.04276183795958851), ('work', 0.06558663393265786)]
# **********************Content from page 42
# **********************Title + Abstract**********************
# Product Sourcing Malaysia Product sourcing of Local Malaysian Herbal Supplement is required. The product sourcing should include details of product registration with KKM Malaysia, manufacturer contact details. Qualified freelancers from Malaysia only with Pharmaceutical knowledge and experience are invited to bid and may contact me for further details upon agreement.
# **********************After checking Similarity from pke pake model**********************
# ['local malaysian herbal supplement', 'product sourcing malaysia product sourcing', 'manufacturer contact details', 'kkm malaysia', 'product registration', 'pharmaceutical knowledge', 'qualified freelancers', 'details', 'experience', 'agreement']
# **********************Top 10 from pke pake model*****************************************
# [('local malaysian herbal supplement', 1.4657954954895404e-06), ('product sourcing malaysia product sourcing', 1.6376803425008468e-06), ('manufacturer contact details', 0.0028762292822287617), ('kkm malaysia', 0.0069897469188272615), ('product registration', 0.009021159404739111), ('pharmaceutical knowledge', 0.038844770579747), ('qualified freelancers', 0.09078468674575876), ('details', 0.12301317865953539), ('experience', 0.2140095546407045), ('agreement', 0.2140095546407045)]
# **********************Content from page 43
# **********************Title + Abstract**********************
# website-26nov2022 Need someone to update few contents on a WordPress website which is in English & Arabic. Bid only if you are familiar with Arabic language. Changes will be made on text, background color, images, and small update in layout for one page.
# **********************After checking Similarity from pke pake model**********************
# ['wordpress website', 'arabic language', 'small update', 'english', 'background color', 'website-26nov2022', 'bid', 'changes', 'text', 'images', 'layout', 'page', 'few contents']
# **********************Top 10 from pke pake model*****************************************
# [('wordpress website', 0.001531225037027196), ('arabic language', 0.008204061108148059), ('small update', 0.028492372522584766), ('english', 0.038282537372335494), ('background color', 0.043200815446162645), ('website-26nov2022', 0.04806507636884328), ('bid', 0.14919824667582093), ('changes', 0.2034988753084348), ('text', 0.2034988753084348), ('images', 0.2034988753084348)]
# **********************Content from page 44
# **********************Title + Abstract**********************
# do-follow backlinks with indexing and not blocked by robots.txt or any meta I need tons of do-follow backlinks with indexing and not blocked by or any meta in page source, to make sure you're not spamming write this word purple in your offer so I can see it and make sure you provide good backlinks like edu and gov
# **********************After checking Similarity from pke pake model**********************
# ['do-follow backlinks', 'good backlinks', 'page source', 'word purple', 'meta', 'indexing', 'tons', 'offer', 'edu', 'gov']
# **********************Top 10 from pke pake model*****************************************
# ...
# **********************Top 10 from pke pake model*****************************************
# [('clothing website', 0.0008728693296917767), ('graphic designer', 0.0012080228843909771), ('clothing brand', 0.0022417118220368643), ('salman malawat owner', 0.007455319477723372), ('requirements', 0.04776309965539685), ('india', 0.10202110342875227), ('freelancer', 0.14835990968886137), ('gulabojaipur', 0.16864218508000267), ('professional', 0.1919532696658623)]
# **********************Content from page 37
# **********************Title + Abstract**********************
# Ubuntu 22 - Nginx, PHP, Ffmpeg updated lo latest versions. Hi, We need a PHP/Web developer to update some libraries on XCUI. XC UI is a streaming software based on PHP, which allows us to manage our Live TV streaming service, resellers and clients. Our version is compatible with ubuntu 18.04 only and we need it to work on latest versions of ubuntu (20/22) with updated libraries. Here are main libraries: Php, Nginx, Ffmpeg, Libcurl, Mysql/mariadb. If you can help us, please get in touch with your price.
# **********************After checking Similarity from pke pake model**********************
# ['xc ui', 'web developer', 'php', 'latest versions', 'nginx', 'ffmpeg', 'ubuntu', 'live tv streaming service', 'main libraries', 'streaming software', 'xcui', 'libcurl', 'mysql', 'resellers', 'clients', 'version', 'mariadb', 'touch', 'price', 'lo']
# **********************Top 10 from pke pake model*****************************************
# [('xc ui', -4.0), ('web developer', 0.021447590019017342), ('php', 0.022210110533850223), ('latest versions', 0.026954153465760383), ('nginx', 0.06569910966489062), ('ffmpeg', 0.06569910966489062), ('ubuntu', 0.07591532454568065), ('live tv streaming service', 0.07942316384107266), ('main libraries', 0.08430421443304136), ('streaming software', 0.09985904247915153)]
# **********************Content from page 38
# **********************Title + Abstract**********************
# european franchise legal news -- 2 I have 3 online business relating to selling online legal services The type of data available are - articles - archive of legal documents - ebooks - webinars - newsletter - glossary of words - court of law décisions - videos - news feeder - online simulators - forum for questions + e commerce function to sell some legal products and services online I am a college educated person with a BA and looking for a remote full time job as community and online marketing manager virtual assistabt and data research
# **********************After checking Similarity from pke pake model**********************
# ['online marketing manager virtual assistabt', 'online legal services', 'online business', 'online simulators', 'legal news', 'remote full time job', 'legal documents', 'legal products', 'news feeder', 'data research', 'law décisions', 'european franchise', 'services', 'type', 'articles', 'ebooks', 'webinars', 'newsletter', 'words', 'court', 'videos', 'forum', 'questions', 'college', 'person', 'community', 'e commerce function', 'archive', 'glossary', 'ba']
# **********************Top 10 from pke pake model*****************************************
# [('online marketing manager virtual assistabt', 6.956535267204613e-08), ('online legal services', 2.645145885223305e-05), ('online business', 0.000951846257943115), ('online simulators', 0.000951846257943115), ('legal news', 0.0010712622529716654), ('remote full time job', 0.0010730841282718736), ('legal documents', 0.0012226568253510663), ('legal products', 0.0012226568253510663), ('news feeder', 0.0013055139628267193), ('data research', 0.0013055139628267193)]
# **********************Content from page 39
# **********************Title + Abstract**********************
# Excel to Browser based Data Analysis - Automate Data Fetching from a website where I have a paid login - This Data I want to analysis in the cloud excel type Environment. For E.g. Google Sheet where RAM of my computer is not used. - Repeat this process at a certain Frequency
# **********************After checking Similarity from pke pake model**********************
# ['cloud excel type environment', 'automate data fetching', 'data analysis', 'e.g. google sheet', 'browser', 'excel', 'certain frequency', 'website', 'login', 'ram', 'computer', 'process']
# **********************Top 10 from pke pake model*****************************************
# [('cloud excel type environment', 2.7935512946586833e-06), ('automate data fetching', 3.2341340709681585e-05), ('data analysis', 0.000645309425670551), ('e.g. google sheet', 0.001104343026558147), ('browser', 0.03178451721206483), ('excel', 0.03776326847322206), ('certain frequency', 0.03823475959167126), ('website', 0.04801005240829256), ('login', 0.04801005240829256), ('ram', 0.10234487023256464)]
# **********************Content from page 40
# **********************Title + Abstract**********************
# Senior Full stack developer Hi Everybody Now I am looking for React and Angular developer. Of course you have to know deep learning about the Backend This is big project and now I want to work with somebody. Who can work with me? Now the door is opened for you. I will ask some question in this here and if you matched about these skill I will hire you Thanks for reading my project detail Will wait for you
# **********************After checking Similarity from pke pake model**********************
# ['angular developer', 'senior full stack developer', 'react', 'big project', 'deep learning', 'project detail', 'backend', 'thanks', 'door', 'question', 'skill']
# **********************Top 10 from pke pake model*****************************************
# [('angular developer', 0.0011968171977008934), ('senior full stack developer', 0.0017532977692328046), ('react', 0.03225418293191354), ('big project', 0.03441437500715755), ('deep learning', 0.04519614197902569), ('project detail', 0.04704903226465435), ('backend', 0.10374545497717468), ('thanks', 0.19088941993809502), ('door', 0.24249564105803367), ('question', 0.2676284071063423)]
# **********************Content from page 41
# **********************Title + Abstract**********************
# Collection of data Hi all, There is simple task in which you need to search company contact details, Rest more we can discuss over chat. Please start bid with "3+2=" answer so that can check that you have read the basic description of the project. Thank you
# **********************After checking Similarity from pke pake model**********************
# ['company contact details', 'simple task', 'basic description', 'collection', 'data', 'chat', 'answer', 'project']
# **********************Top 10 from pke pake model*****************************************
# [('company contact details', 8.616039319008966e-05), ('simple task', 0.0019471835175045684), ('basic description', 0.02476488287747334), ('collection', 0.04408400347403095), ('data', 0.04408400347403095), ('chat', 0.04408400347403095), ('answer', 0.13805546025857632), ('project', 0.13805546025857632)]
# **********************Content from page 42
# **********************Title + Abstract**********************
# Java GUI and server side service as web At phase 1, develop the client-side interface in such a way that could access the system via web browser while the system administrators should access the system via a java application. Ensure that the following tasks are properly provided: For student users 1. After a successful login process the student should be able to view all his groups. The members, groups and associated resource ids are, previously saved as JSON file(s) in the server, should be retrieved and displayed. For system administrators: 1. After a successful login process, system administrator should be able to view all available groups. 2. System administrator should be able to add, delete or modify groups and their members and resources. 3. System administrator should be able to search for groups, members and res...
# **********************After checking Similarity from pke pake model**********************
# ['java gui', 'web browser', 'java application', 'client-side interface', 'successful login process', 'system administrator', 'system administrators', 'student users', 'groups', 'json file(s', 'phase', 'way', 'members', 'resource ids', 'server side service', 'server', 'tasks', 'resources', 'res']
# **********************Top 10 from pke pake model*****************************************
# [('java gui', 0.0020170604796757516), ('web browser', 0.003382578601192149), ('java application', 0.003382578601192149), ('client-side interface', 0.004042720448922122), ('successful login process', 0.013926084616811928), ('system administrator', 0.016781519969473586), ('student users', 0.036909382157833626), ('groups', 0.04983604560734958), ('json file(s', 0.061647939547463296), ('phase', 0.06345425649092873)]
# **********************Content from page 43
# **********************Title + Abstract**********************
# Update PHP, ffmpeg and nginx to latest versions and get it working on Ubuntu 22 Hi, We need a PHP/Web developer to update some libraries on XC Software XC UI is a streaming software based on PHP, which allows us to manage our Live TV streaming service, resellers and clients. Our version is compatible with ubuntu 18.04 only and we need it to work on latest versions of ubuntu (20/22) with updated libraries. Here are main libraries: Php Nginx Ffmpeg Libcurl Mysql/mariadb If you can help us, please get in touch with your price.
# **********************After checking Similarity from pke pake model**********************
# ['xc software xc ui', 'php nginx ffmpeg libcurl mysql', 'web developer', 'live tv streaming service', 'streaming software', 'update php', 'latest versions', 'ubuntu', 'main libraries', 'resellers', 'clients', 'ffmpeg', 'version', 'mariadb', 'touch', 'price']
# **********************Top 10 from pke pake model*****************************************
# [('xc software xc ui', -0.1387333386999735), ('php nginx ffmpeg libcurl mysql', 1.4586767022269029e-05), ('web developer', 0.001688332612179122), ('live tv streaming service', 0.0020536600418604527), ('streaming software', 0.0024627956847884823), ('update php', 0.0027679123804317035), ('latest versions', 0.005451845432212633), ('ubuntu', 0.020747406531647836), ('main libraries', 0.025806279153796494), ('resellers', 0.05098201561978481)]
# **********************Content from page 44
# **********************Title + Abstract**********************
# Website graphic revamp Hello, It's time to give my site a fresh new look and I'm looking for quotes to deliver: - logo refresh to be delivered also in vectorial format - wireframe for 4 templates (home, working experience, blog, contact). - html and CSS coding for the agreed design to return a set of responsive templates that run locally (plain simple html code without any framework, vanilla Js can be used). Some sliding functionalities are expected. Site to be redesigned will be communicated to the selected provider. Please provide your price range, estimated delivery time.
# **********************After checking Similarity from pke pake model**********************
# ['website graphic revamp hello', 'fresh new look', 'plain simple html code', 'logo refresh', 'vectorial format', 'responsive templates', 'css coding', 'delivery time', 'quotes', 'wireframe', 'home', 'experience', 'blog', 'contact', 'site', 'price range', 'html', 'design', 'set', 'framework', 'functionalities', 'provider', 'vanilla js']
# **********************Top 10 from pke pake model*****************************************
# [('website graphic revamp hello', 7.4754483875411066e-06), ('fresh new look', 0.0003052968505506373), ('plain simple html code', 0.0006722564718645422), ('logo refresh', 0.0028818663828432834), ('vectorial format', 0.0028818663828432834), ('responsive templates', 0.01476406888434222), ('css coding', 0.03754631598708786), ('delivery time', 0.05119323185036008), ('quotes', 0.053605830788833304), ('wireframe', 0.053605830788833304)]
# **********************Content from page 45
# **********************Title + Abstract**********************
# Build Web App Nutrition -- 2 The project is a nutrition web app. As i am informed my host supports PHP and not .NET. Basics of the project are: CRM Build a meal plan from scratch. Automatic Generator of meal plans instantly. Appointment Calendar. Online payments. Future Developement: Developer should be able to build a mobile app interacting with the web app. There are the core ideas. Of course details will be shared.
# **********************After checking Similarity from pke pake model**********************
# ['build web app nutrition', 'crm build', 'meal plan', 'mobile app', 'appointment calendar', 'project', 'automatic generator', 'future developement', 'php', 'online payments', 'core ideas', 'host', 'developer', 'basics', 'scratch', 'details']
# **********************Top 10 from pke pake model*****************************************
# [('build web app nutrition', 0.0001687877906289323), ('crm build', 0.02385344928385131), ('meal plan', 0.05687910675148483), ('mobile app', 0.060323649025853236), ('appointment calendar', 0.07178412389138139), ('project', 0.07303179096532496), ('automatic generator', 0.07850714455248209), ('future developement', 0.09319983309033328), ('php', 0.11743348076526518), ('online payments', 0.1262118100844195)]
# **********************Content from page 46
# **********************Title + Abstract**********************
# Add text to STL I’d like to add graphics and text (svg) to an existing stl file
# **********************After checking Similarity from pke pake model**********************
# ['stl file', 'text', 'graphics', 'svg']
# **********************Top 10 from pke pake model*****************************************
# [('stl file', 0.0008698204675764625), ('text', 0.014551560170359296), ('graphics', 0.03531924477420881), ('svg', 0.03531924477420881)]
# **********************Content from page 47
# **********************Title + Abstract**********************
# Make me MIS dashboard for My Company We want to hire an consultant to make the MIS of my company which is in Capital Incentive Manufacturing Industry
# **********************After checking Similarity from pke pake model**********************
# ['capital incentive manufacturing industry', 'mis dashboard', 'company', 'consultant']
# **********************Top 10 from pke pake model*****************************************
# [('capital incentive manufacturing industry', 4.1047028581555405e-07), ('mis dashboard', 0.0007193620651074846), ('company', 0.011951189368156211), ('consultant', 0.034588515384495436)]
# **********************Content from page 48
# **********************Title + Abstract**********************
# React Native CLI We have Taxi App there was some error on running in app so i thing we need to upgrade library. Main purpose is that we need to remove the error.
# **********************After checking Similarity from pke pake model**********************
# ['taxi app', 'native cli', 'main purpose', 'error', 'react', 'thing', 'library']
# **********************Top 10 from pke pake model*****************************************
# [('taxi app', 0.0008299301649065375), ('native cli', 0.0010394849495738525), ('main purpose', 0.023686557545801627), ('error', 0.03318182716823762), ('react', 0.043156541891782876), ('thing', 0.043156541891782876), ('library', 0.043156541891782876)]
# **********************Content from page 49
# **********************Title + Abstract**********************
# COSMETIC PRODUCTS SALESMAN REQUIRED I need a salesman for Marketing purpose for cosmetic products.
# **********************After checking Similarity from pke pake model**********************
# ['cosmetic products salesman required', 'marketing purpose', 'salesman']
# **********************Top 10 from pke pake model*****************************************
# [('cosmetic products salesman required', 6.477600380531913e-07), ('marketing purpose', 0.0009261601707777732), ('salesman', 0.025009793197086395)]
# **********************Content from page 50
